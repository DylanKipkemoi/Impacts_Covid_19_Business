# %%
#!/usr/bin/env python
# coding: utf-8

# In[16]:


import pandas as pd

df = pd.read_excel ('/home/dylan/Downloads/both_Grants[1] (1).xlsx', nrows=1000)

print(df)

# change dataframe to array
data=df.to_numpy()

print(df)


# In[ ]:





# In[ ]:
# Out:
#      Year                     NS Small Business  \
# 0    2020                HFX Sports Bar & Grill
# 1    2020                       1 World Trading
# 2    2020          2nd Glance Hair & Aesthetics
# 3    2020                         30 Minute Hit
# 4    2020                         30 Minute Hit
# ..    ...                                   ...
# 995  2020              Hidden Gem Hair Boutique
# 996  2020                        Hideaway Salon
# 997  2020                 Highland Arts Theatre
# 998  2020          Highland Chiropractic Clinic
# 999  2020  Highland District Soccer Association
#
#                           Type of Business  \
# 0                   Drinking establishment
# 1    In-person trade shows and exhibitions
# 2                    Personal care service
# 3                    Fitness establishment
# 4                    Fitness establishment
# ..                                     ...
# 995                  Personal care service
# ...

# %%
#!/usr/bin/env python
# coding: utf-8

# In[16]:


import pandas as pd

df = pd.read_excel ('/home/dylan/Downloads/Receieved_1st_grant[1] (1).xlsx', nrows=1000)

print(df)

# change dataframe to array
data=df.to_numpy()

print(df)


# In[ ]:





# In[ ]:

# %%
#!/usr/bin/env python
# coding: utf-8

# In[20]:


import pandas as pd

df = pd.read_excel ('/home/dylan/Downloads/both_Grants[1] (1).xlsx')

"Sort data based on Price"
df.sort_values(by=['Type of Business'], inplace=True)

"Scatter Plot in Pandas"
plot1=df.hist(column="Year", bins=50)


# In[ ]:





# In[ ]:





# In[ ]:

# %%
#!/usr/bin/env python
# coding: utf-8

# In[10]:


import pandas as pd

df = pd.read_excel ('/home/dylan/Downloads/both_Grants[1] (1).xlsx',nrows=800)

"Sort data based on X"
df.sort_values(by=['Type of Business'], inplace=True)

"Line Plot in Pandas"
# plot1 = df.plot.line() # draw all data where x is unlabeled data number
plot2 = df.plot.line(x="Type of Business")


# In[ ]:

# %%
#!/usr/bin/env python
# coding: utf-8

# In[16]:


import pandas as pd

df = pd.read_excel ('/home/dylan/Downloads/both_Grants[1] (1).xlsx',nrows=10)

"Sort data based on X"
df.sort_values(by=['Received Small Business Impact Grant'], inplace=True)



"Scatter Plot in Pandas"
plot1=df.plot.scatter(x="Received Small Business Impact Grant",
                      y="NS Small Business",
                      s=100,
                      c='blue')


# In[ ]:

# %%
#!/usr/bin/env python
# coding: utf-8

# In[38]:


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel ('/home/dylan/Downloads/both_Grants[1] (1).xlsx')

x = df['Received Small Business Impact Grant'] 
y = df['Type of Business'] 
plt.scatter(x,y)

plt.title("plot of the relationship between the Type of Business and businesses that received both grants ")
plt.show()


# In[ ]:





# In[ ]:
